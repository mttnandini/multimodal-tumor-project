# %%
import sys, os

# get absolute path to cnn_model.py folder
model_src_path = os.path.join(os.getcwd(), "data", "notebooks", "models", "src")
sys.path.append(model_src_path)

print("✅ Added path:", model_src_path)
# Out:
# ✅ Added path: C:\Users\mttna\OneDrive\Desktop\jupyter\multimodal-tumor-project\data\notebooks\models\src

# %%
import os
print("✅ Notebook connected successfully!")
print("Current working directory:", os.getcwd())
# Out:
# ✅ Notebook connected successfully!
# Current working directory: C:\Users\mttna\OneDrive\Desktop\jupyter\multimodal-tumor-project

# %%
import sys, os

# add the folder containing cnn_model.py and utils.py to Python’s path
sys.path.append(os.path.join(os.getcwd(), "data", "notebooks", "models", "src"))

print("✅ Path added successfully!")
# Out:
# ✅ Path added successfully!

# %%
import tensorflow as tf
import torch
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

print("✅ Environment is ready for the Multimodal Tumor Project!")
print("TensorFlow version:", tf.__version__)
print("PyTorch version:", torch.__version__)
# Out:
# ✅ Environment is ready for the Multimodal Tumor Project!
# TensorFlow version: 2.20.0
# PyTorch version: 2.9.0+cpu

# %%
import os
print(os.listdir(os.path.join(os.getcwd(), "data", "notebooks", "models", "src")))
# Out:
# ['.ipynb_checkpoints', 'preprocess.py', 'README.md', 'requirements.txt', 'utils.py', '__pycache__']

# %%
import os

for root, dirs, files in os.walk(os.getcwd()):
    if "cnn_model.py" in files:
        print("Found cnn_model.py at:", root)
# Out:
# Found cnn_model.py at: C:\Users\mttna\OneDrive\Desktop\jupyter\multimodal-tumor-project\data\notebooks\models

# %%
import sys
sys.path.append(r"C:\Users\mttna\OneDrive\Desktop\jupyter\multimodal-tumor-project\data\notebooks\models")

from cnn_model import CNNModel
from utils import count_parameters

model = CNNModel()
print("✅ Model loaded successfully!")
print("Trainable Parameters:", count_parameters(model))
# Out:
# ✅ Model loaded successfully!
# Trainable Parameters: 25710793

# %%
from fusion_model import FusionModel

fusion = FusionModel()
print("✅ Fusion model loaded successfully!")
# Out:
# ✅ Fusion model loaded successfully!

# %%
from preprocess import load_datasets

# this goes up 3 levels from "notebooks/models/src" to your root folder
base_dir = os.path.join(os.getcwd(), "data")

radiology_train, radiology_val, pathology_train, pathology_val = load_datasets(base_dir)

images, labels = next(iter(radiology_train))
print("✅ Dataset loaded successfully!")
print("Batch shape:", images.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 6
#       3 # this goes up 3 levels from "notebooks/models/src" to your root folder
#       4 base_dir = os.path.join(os.getcwd(), "data")
# ----> 6 radiology_train, radiology_val, pathology_train, pathology_val = load_datasets(base_dir)
#       8 images, labels = next(iter(radiology_train))
#       9 print("✅ Dataset loaded successfully!")
#
# File ~\OneDrive\Desktop\jupyter\multimodal-tumor-project\data\notebooks\models\src\preprocess.py:17, in load_datasets(base_dir, batch_size)
#      14 radiology_path = os.path.join(base_dir, "radiology")
#      15 pathology_path = os.path.join(base_dir, "pathology")
# ---> 17 radiology_dataset = datasets.ImageFolder(root=radiology_path, transform=transform)
#      18 pathology_dataset = datasets.ImageFolder(root=pathology_path, transform=transform)
# ...

# %%
import os

for folder in ["radiology", "pathology"]:
    path = os.path.join("data", folder)
    print(folder, "->", os.listdir(path))
# Out:
# radiology -> ['normal', 'tumor']
# pathology -> ['normal', 'tumor']

# %%
from preprocess import load_datasets

base_dir = os.path.join(os.getcwd(), "data")

radiology_train, radiology_val, pathology_train, pathology_val = load_datasets(base_dir)

images, labels = next(iter(radiology_train))
print("✅ Dataset loaded successfully!")
print("Batch shape:", images.shape)
# Out:
# ✅ Radiology and Pathology datasets loaded successfully!
# Radiology samples: 4 | Pathology samples: 4
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[18], line 7
#       3 base_dir = os.path.join(os.getcwd(), "data")
#       5 radiology_train, radiology_val, pathology_train, pathology_val = load_datasets(base_dir)
# ----> 7 images, labels = next(iter(radiology_train))
#       8 print("✅ Dataset loaded successfully!")
#       9 print("Batch shape:", images.shape)
#
# File ~\OneDrive\Desktop\jupyter\multimodal-tumor-project\venv\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
# ...
